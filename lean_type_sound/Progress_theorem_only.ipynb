# %% [markdown]
# # Analyze Lean Code Progress in `lean_type_sound`
#
# This notebook parses the `.lean` files in `LeanTypeSound` to count the number of theorems, lemmas, and definitions, and checks how many are implemented (vs. left as `sorry`, which represents stubbed code generally produced initially or left unproven).

# %%
import os
import glob
import re
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Configure Parsing Regex and Logic
#
# We need to identify Lean blocks:
# - `def ... :=`
# - `theorem ... :=`
# - `lemma ... :=`
#
# And within each block, we check if the `sorry` block is present. If a block has `sorry`, it's an unproven stub. If not, it is fully implemented/proven.

# %%
# Regex patterns to locate declarations in Lean 4
# Matches lines starting with `theorem ` or `lemma `
declaration_pattern = re.compile(r'^\s*(theorem|lemma)\s+([a-zA-Z0-9_\']+)', re.MULTILINE)

# Target directory
target_dir = "LeanTypeSound"

def extract_blocks(content):
    """
    Extracts each declaration block from a Lean file string.
    A block starts from a match of declaration_pattern and runs up to the next match.
    """
    matches = list(declaration_pattern.finditer(content))
    blocks = []
    
    for i in range(len(matches)):
        start_idx = matches[i].start()
        end_idx = matches[i+1].start() if i + 1 < len(matches) else len(content)
        
        block = content[start_idx:end_idx]
        decl_type = matches[i].group(1)
        name = matches[i].group(2)
        
        blocks.append({
            'type': decl_type,
            'name': name,
            'content': block
        })
    return blocks

def is_proven(block):
    """
    A block is 'proven/implemented' if it does not contain 'sorry'.
    """
    if 'sorry' in block['content']:
        return False
    return True

# %% [markdown]
# ## Scan and Parsen Lean Files
#
# Traverse all files under `LeanTypeSound` and analyze them.

# %%
results = []

print(f"Scanning target directory: {target_dir}")
for file_path in glob.glob(os.path.join(target_dir, "*.lean")):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()
    
    blocks = extract_blocks(content)
    
    for block in blocks:
        is_impl = is_proven(block)
        results.append({
            "File": os.path.basename(file_path),
            "Type": block['type'],
            "Name": block['name'],
            "Is_Proven": is_impl
        })

df = pd.DataFrame(results)
print(f"Total theorems found: {len(df)}")
df.head()
# Out:
# Scanning target directory: LeanTypeSound
# Total theorems found: 256
#                  File     Type                         Name  Is_Proven
# 0       Evaluate.lean  theorem               evaluate_clock      False
# 1       Evaluate.lean  theorem           fix_clock_evaluate      False
# 2       Evaluate.lean  theorem        fix_clock_do_eval_res      False
# 3  EvaluateProps.lean  theorem         io_events_mono_trans      False
# 4  EvaluateProps.lean  theorem  call_FFI_rel_io_events_mono      False

# %%
# List out all the theorems/lemmas that are still stubbed out with 'sorry'
unproven_theorems = df[df['Is_Proven'] == False]

print(f"Found {len(unproven_theorems)} unproven theorems:")
for _, row in unproven_theorems.iterrows():
    print(f" - {row['File']}: {row['Name']}")
# Out:
# Found 157 unproven theorems:
#  - Evaluate.lean: evaluate_clock
#  - Evaluate.lean: fix_clock_evaluate
#  - Evaluate.lean: fix_clock_do_eval_res
#  - EvaluateProps.lean: io_events_mono_trans
#  - EvaluateProps.lean: call_FFI_rel_io_events_mono
#  - EvaluateProps.lean: io_events_mono_refl
#  - EvaluateProps.lean: do_app_call_FFI_rel
#  - EvaluateProps.lean: do_app_io_events_mono
#  - EvaluateProps.lean: is_clock_io_mono_cong
#  - EvaluateProps.lean: is_clock_io_mono_return
#  - EvaluateProps.lean: is_clock_io_mono_err
#  - EvaluateProps.lean: is_clock_io_mono_bind
#  - EvaluateProps.lean: is_clock_io_mono_check
#  - EvaluateProps.lean: do_app_refs_length
#  - EvaluateProps.lean: is_clock_io_mono_do_app_simple
#  - EvaluateProps.lean: is_clock_io_mono_evaluate
#  - EvaluateProps.lean: is_clock_io_mono_evaluate_decs
#  - EvaluateProps.lean: is_clock_io_mono_extra
#  - EvaluateProps.lean: evaluate_length
#  - EvaluateProps.lean: is_clock_io_mono_set_clock
#  - EvaluateProps.lean: is_clock_io_mono_minimal
#  - EvaluateProps.lean: can_pmatch_all_EVERY
#  - Misc.lean: CARD_IMAGE_ID_BIJ
#  - Misc.lean: tlookup_bij_suff
#  - Misc.lean: tlookup_bij_iff
#  - Mlstring.lean: explode_aux_thm
#  - Mlstring.lean: explode_thm
#  - Mlstring.lean: explode_implode
#  - Mlstring.lean: implode_explode
#  - Mlstring.lean: explode_11
#  - Mlstring.lean: TOKENS_eq_tokens_aux
#  - Mlstring.lean: TOKENS_eq_tokens
#  - NamespaceProps.lean: nsLookup_nsSing
#  - NamespaceProps.lean: nsAll_nsSing
#  - NamespaceProps.lean: nsAll2_nsSing
#  - NamespaceProps.lean: nsBind_11
#  - NamespaceProps.lean: nsLookup_nsAppend_some
#  - NamespaceProps.lean: nsLookupMod_nsAppend_none
#  - NamespaceProps.lean: nsAll_nsLift
#  - NamespaceProps.lean: nsSub_nsBind
#  - NamespaceProps.lean: nsSub_nsAppend2
#  - NamespaceProps.lean: alist_rel_restr_thm
#  - NamespaceProps.lean: nsLookup_FOLDR_nsLift_some
#  - NamespaceProps.lean: nsLookupMod_FOLDR_nsLift_none
#  - NamespaceProps.lean: nsAll2_nsBind
#  - NamespaceProps.lean: nsAll2_nsBindList
#  - NamespaceProps.lean: nsAll2_nsAppend
#  - NamespaceProps.lean: nsAll2_alist_to_ns
#  - NamespaceProps.lean: nsAll2_nsLift
#  - SemanticPrimitivesProps.lean: pat_bindings_accum
#  - SemanticPrimitivesProps.lean: build_rec_env_merge
#  - SemanticPrimitivesProps.lean: FV_pes_MAP
#  - SemanticPrimitivesProps.lean: FV_defs_MAP
#  - TypeSound.lean: prim_canonical_values_thm
#  - TypeSound.lean: has_lists_v_to_list
#  - TypeSound.lean: ctor_canonical_values_thm
#  - TypeSound.lean: eq_same_type
#  - TypeSound.lean: type_env_conv_thm
#  - TypeSound.lean: type_funs_fst
#  - TypeSound.lean: type_recfun_env_help
#  - TypeSound.lean: type_recfun_env
#  - TypeSound.lean: type_v_exn
#  - TypeSound.lean: type_v_Boolv
#  - TypeSound.lean: opapp_type_sound
#  - TypeSound.lean: store_assign_type_sound
#  - TypeSound.lean: store_alloc_type_sound
#  - TypeSound.lean: type_v_list_to_v
#  - TypeSound.lean: type_v_list_to_v_APPEND
#  - TypeSound.lean: do_eq_Boolv
#  - TypeSound.lean: prim_canonical_Boolv_thm
#  - TypeSound.lean: prim_canonical_Boolv_cases
#  - TypeSound.lean: op_type_sound
#  - TypeSound.lean: build_conv_type_sound
#  - TypeSound.lean: same_ctor_and_same_tid
#  - TypeSound.lean: pat_type_sound
#  - TypeSound.lean: lookup_var_sound
#  - TypeSound.lean: EVERY_REPLICATE
#  - TypeSound.lean: exp_type_sound
#  - TypeSound.lean: build_tdefs_build_tenv
#  - TypeSound.lean: type_sound_invariant_union
#  - TypeSound.lean: check_ctor_tenv_dups
#  - TypeSound.lean: type_all_env_extend
#  - TypeSound.lean: type_e_con_check
#  - TypeSound.lean: decs_type_sound_no_check
#  - TypeSound.lean: decs_type_sound
#  - TypeSound.lean: semantics_type_sound
#  - TypeSysProps.lean: check_freevars_subst_single
#  - TypeSysProps.lean: deBuijn_inc_lem1
#  - TypeSysProps.lean: type_subst_deBruijn_inc_single
#  - TypeSysProps.lean: type_subst_deBruijn_inc_list
#  - TypeSysProps.lean: deBruijn_subst_check_freevars
#  - TypeSysProps.lean: deBruijn_subst_check_freevars2
#  - TypeSysProps.lean: check_freevars_subst_inc
#  - TypeSysProps.lean: check_freevars_subst
#  - TypeSysProps.lean: type_subst_deBruijn_subst_single
#  - TypeSysProps.lean: type_subst_deBruijn_subst_list
#  - TypeSysProps.lean: check_freevars_lem
#  - TypeSysProps.lean: nil_deBruijn_subst
#  - TypeSysProps.lean: deBruijn_subst2_thm
#  - TypeSysProps.lean: type_e_subst_lem3
#  - TypeSysProps.lean: type_e_subst_lem5
#  - TypeSysProps.lean: subst_inc_cancel
#  - TypeSysProps.lean: type_e_subst_lem7
#  - TypeSysProps.lean: deBruijn_subst_id
#  - TypeSysProps.lean: deBruijn_subst_freevars
#  - TypeSysProps.lean: check_freevars_type_name_subst
#  - TypeSysProps.lean: tveLookup_freevars_thm
#  - TypeSysProps.lean: tveLookup_freevars_local
#  - TypeSysProps.lean: tveLookup_subst_some
#  - TypeSysProps.lean: tveLookup_inc_some
#  - TypeSysProps.lean: tveLookup_freevars_subst
#  - TypeSysProps.lean: tveLookup_no_tvs
#  - TypeSysProps.lean: type_ps_length
#  - TypeSysProps.lean: type_p_freevars
#  - TypeSysProps.lean: type_p_subst
#  - TypeSysProps.lean: type_p_bvl
#  - TypeSysProps.lean: type_p_tenvV_indep
#  - TypeSysProps.lean: type_es_list_rel
#  - TypeSysProps.lean: type_es_length
#  - TypeSysProps.lean: tenv_val_exp_ok_bvl_funs
#  - TypeSysProps.lean: type_e_freevars
#  - TypeSysProps.lean: type_e_subst
#  - TypeSysProps.lean: type_funs_Tfn
#  - TypeSysProps.lean: type_funs_lookup
#  - TypeSysProps.lean: type_funs_find_recfun
#  - TypeSysProps.lean: type_recfun_lookup
#  - TypeSysProps.lean: type_funs_distinct
#  - TypeSysProps.lean: type_e_subst_lem
#  - TypeSysProps.lean: mem_type_def_to_ctMap
#  - TypeSysProps.lean: ctMap_ok_merge_imp
#  - TypeSysProps.lean: type_def_to_ctMap_mem
#  - TypeSysProps.lean: fupdate2_union
#  - TypeSysProps.lean: ctMap_ok_type_defs
#  - TypeSysProps.lean: nsLookup_add_tenvE1
#  - TypeSysProps.lean: nsLookup_add_tenvE2
#  - TypeSysProps.lean: type_v_freevars
#  - TypeSysProps.lean: type_subst_thm
#  - TypeSysProps.lean: check_ctor_tenv_ok
#  - TypeSysProps.lean: type_d_check_uniq
#  - TypeSysProps.lean: type_d_tenv_ok_helper
#  - TypeSysProps.lean: type_d_tenv_ok
#  - TypeSysProps.lean: type_ds_sing
#  - TypeSysProps.lean: lookup_tenv_names
#  - TypeSysProps.lean: tenv_names_bind_var_list
#  - Weakening.lean: weak_tenv_refl
#  - Weakening.lean: weak_tenvE_freevars
#  - Weakening.lean: weak_tenvE_bind_tvar2
#  - Weakening.lean: type_p_weakening
#  - Weakening.lean: type_e_weakening_lem
#  - Weakening.lean: type_e_weakening
#  - Weakening.lean: type_tenv_ctor_weakening
#  - Weakening.lean: type_tenv_val_weakening_lemma
#  - Weakening.lean: type_v_weakening
#  - Weakening.lean: type_all_env_weakening
#  - Weakening.lean: type_sv_weakening
#  - Weakening.lean: type_s_weakening
#  - Weakening.lean: weak_tenv_extend_dec_tenv

# %% [markdown]
# ## Calculate and Display Percentages
#
# Calculate ratio of Claude-proven constructs to total count, and visualize this in a plot mapping completion rate.

# %%
# Breakdown by Completion
summary_all = df['Is_Proven'].value_counts()
total_constructs = len(df)
proven_count = summary_all.get(True, 0)
unproven_count = summary_all.get(False, 0)

percentage_proven = (proven_count / total_constructs) * 100 if total_constructs > 0 else 0

print("=== OVERALL PROGRESS ===")
print(f"Total Constructs: {total_constructs}")
print(f"Proven/Implemented (Non-sorry): {proven_count} ({percentage_proven:.2f}%)")
print(f"Unproven/Stubbed (Sorry): {unproven_count} ({(100 - percentage_proven):.2f}%)\n")

# Breakdown by Type
breakdown_type = df.groupby(['Type', 'Is_Proven']).size().unstack(fill_value=0)
print("=== BREAKDOWN BY CONSTRUCT TYPE ===")
print(breakdown_type)

# Plot Overall Progress
plt.figure(figsize=(6, 6))
labels = ['Proven/Implemented', 'Stubbed/Sorry']
sizes = [proven_count, unproven_count]
colors = ['#4CAF50', '#FF5722']
explode = (0.1, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title(f"Overall Lean Code Implementation Progress\n({total_constructs} total constructs)")
plt.axis('equal') 
plt.show()
# Out:
# === OVERALL PROGRESS ===
# Total Constructs: 256
# Proven/Implemented (Non-sorry): 99 (38.67%)
# Unproven/Stubbed (Sorry): 157 (61.33%)
#
# === BREAKDOWN BY CONSTRUCT TYPE ===
# Is_Proven  False  True
# Type
# theorem      157     99
